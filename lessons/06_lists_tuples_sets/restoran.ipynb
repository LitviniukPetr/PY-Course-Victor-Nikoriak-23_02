# %% [markdown]
# # Створюємо дані

# %%
from enum import unique

orders = [

    ("Іван", 450, 5),
    ("Катя", 650, 10),
    ("Сергій", 450, 10),
    ("Марія", 350, 30),
    ("Іван", 400, 30),
    ("Катя", 700, 30),
    ("Сергій", 670, 20),
    ("Марія", 1050, 100),
    ("Катя", 750, 10),
    ("Сергій", 500, 20),
    ("Марія", 750, 150),
    ("Іван", 700, 25),
    ("Катя", 650, 65),
    ("Марія", 650, 100),
    ("Сергій", 500, 50),

]

# %%
for order in orders[:3]:
    print(order)

# %%
first_order = orders[0][0]
second_order = orders[0][1]
third_order = orders[0][2]
print(first_order)
print(second_order)
print('Чайові',third_order)

# %%
# from typing import NamedTuple
#
# class Order(NamedTuple):
#     waiter: str
#     bill: float
#     tip: float
#
#
# named_orders = [
#     Order("Марія", 650, 10),
#     Order("Іван", 450, 5),
#     Order("Катя", 650, 10),
#     Order("Сергій", 450, 10),
#     Order("Марія", 350, 30),
#     Order("Іван", 400, 30),
#     Order("Катя", 700, 30),
#     Order("Сергій", 670, 20),
#     Order("Марія", 1050, 100),
#     Order("Катя", 750, 10),
#     Order("Сергій", 500, 20),
#     Order("Марія", 750, 150),
#     Order("Іван", 700, 25),
#     Order("Катя", 650, 65),
#
# ]

# %%
# print(named_orders)
# for order in named_orders:
#     print(order.waiter)
#     print(order.bill)
#     print(order.tip)

# %% [markdown]
# # Алгоритм обробки чеків

# %%
print(len(orders))

# %%
dict_tips_waiter = {}

i = 0
while i < len(orders):
    print(orders[i])
    order = orders[i]
    waiter = order[0]
    tip = order[2]

    if waiter not in tips_waiter:
        tips_waiter[waiter] = 0

    tips_waiter[waiter] += tip
    i += 1

for waiter, tip in tips_waiter.items():
    print(waiter, tip)

# %%
print(tips_waiter.items())

# %%
print(type(tips_waiter.items()))
print(type(list(tips_waiter.items())))

# %% [markdown]
# # Пошук лідера

# %%
waiters_list = list(tips_waiter.items())
print(waiters_list[0])

leader = waiters_list[0][0]
max_tips = waiters_list[0][1]

print(f"leader: {leader}, max_tips: {max_tips}")

i = 1

while i < len(waiters_list):
    waiter, tips = waiters_list[i]

    if tips > max_tips:
        leader = waiter
        max_tips = tips
        print(f"New leader: {leader}, max_tips: {max_tips}")
    else:
        print(f"{waiter} ({tips} грн) - не перевищує  {max_tips}")

    i +=1

print('='*50)
print(f'Лідер за зміну: {leader} максимальні чайові становили {max_tips} грн')

# %%
leader_v2 = max(tips_waiter, key=tips_waiter.get)

print(leader)
print(leader_v2)
print(f"Однакові {leader==leader_v2}")

leader_v3, max_v3 = max(tips_waiter.items(), key= lambda item: item[1])
print(f" {leader_v3} -> {max_v3}")

# %% [markdown]
# # Унікальний офіціант

# %%
unique_waiters = set()

i = 0
while i < len(orders):
    waiter = orders[i][0]
    unique_waiters.add(waiter)
    i += 1

print(f" Унікальних офіціантів  ->  {unique_waiters}")
print('='*50)
print(f"Кількість                    {len(unique_waiters)}")

# %%
unique_waiters_2 = set()

for order in orders:
    print(f'{order} - {len(orders)}order')
    start = len(unique_waiters_2)
    unique_waiters_2.add(order[0])
    finish = len(unique_waiters_2)
    status = "Додано" if finish > start else "вже є"
    print(f"[{status}] '{order[0]:<10}' -> {unique_waiters_2}")

# %%
uniqu_3 = set(orders[])

# %%
print(uniqu_3)

# %%
unique_waiters_4 = set(order[0] for order in orders)

# %%
print(unique_waiters_4)

# %%
sorted_waiters = sorted(orders,  reverse=True)

for waiter, tip in sorted_waiters:
    print(waiter, tip)

# %%
from collections import Counter

orders_counter = Counter(bill for waiter, bill , tip in orders)
print(orders_counter)
